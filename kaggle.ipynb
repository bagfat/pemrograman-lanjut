# %% [markdown]
# <a href="https://colab.research.google.com/github/bagfat/pemrograman-lanjut/blob/main/kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d sgoutami/spotify-streaming-history
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sgoutami/spotify-streaming-history
# License(s): MIT
# ...
#   0% 0.00/6.09M [00:00<?, ?B/s]
# 100% 6.09M/6.09M [00:00<00:00, 1.65GB/s]

# %%
# Replace "dataset-name.zip" with the actual name of your downloaded zip file
# Use "!ls" to see the file name if you're unsure
# !unzip -q spotify-streaming-history.zip

# %%
import pandas as pd

# First, check the extracted file names
# !ls

# Replace "file.csv" with the actual name of your data file
df = pd.read_csv("spotify_history.csv")

# Display the first few rows to confirm it loaded correctly
df.head()
# Out:
# kaggle.json  sample_data  spotify_history.csv  spotify-streaming-history.zip
#         spotify_track_uri                   ts    platform  ms_played  \
# 0  2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185
# 1  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 2  487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# 3  5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022
# 4  0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0
#
#                                       track_name        artist_name  \
# 0                            Say It, Just Say It       The Mowgli's
# 1  Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris
# 2                                    Born To Die       Lana Del Rey
# 3                               Off To The Races       Lana Del Rey
# 4                                      Half Mast  Empire Of The Sun
#
# ...
